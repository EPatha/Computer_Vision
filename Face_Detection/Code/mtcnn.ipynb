# %%
# %pip install matplotlib
import os
import cv2
from mtcnn import MTCNN
import matplotlib.pyplot as plt

# Fungsi untuk mendeteksi dan menyimpan wajah yang terdeteksi pada gambar
def save_face_crop(image_path, output_folder):
    # Inisialisasi MTCNN
    detector = MTCNN()

    # Membaca gambar
    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Ubah ke RGB untuk matplotlib

    # Deteksi wajah
    faces = detector.detect_faces(img)

    if faces:
        for i, face in enumerate(faces):
            # Mengambil koordinat wajah
            x1, y1, width, height = face['box']
            x2, y2 = x1 + width, y1 + height

            # Crop wajah dari gambar
            cropped_face = img[y1:y2, x1:x2]

            # Membuat folder output jika belum ada
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)
            
            # Menyimpan gambar crop wajah dengan nama sesuai subfolder dan ID
            file_name = f"face_{i+1}.ppm"
            output_path = os.path.join(output_folder, file_name)
            cv2.imwrite(output_path, cropped_face)
            print(f"Face saved to {output_path}")
    else:
        print(f"No faces detected in {image_path}")

# Fungsi untuk memproses seluruh gambar dalam direktori
def process_directory(input_dir, output_dir):
    for class_folder in os.listdir(input_dir):
        class_path = os.path.join(input_dir, class_folder)
        
        # Periksa apakah itu folder dan bukan file
        if os.path.isdir(class_path):
            class_output_dir = os.path.join(output_dir, class_folder)
            
            for image_file in os.listdir(class_path):
                image_path = os.path.join(class_path, image_file)
                
                # Periksa apakah file berformat ppm
                if image_file.endswith('.ppm'):
                    save_face_crop(image_path, class_output_dir)

# Path direktori training dan validation
train_dir = 'data/train/'
val_dir = 'data/val/'

# Path output untuk hasil crop wajah
train_output_dir = 'data/train_crops/'
val_output_dir = 'data/val_crops/'

# Proses seluruh gambar dalam direktori train dan val
process_directory(train_dir, train_output_dir)
process_directory(val_dir, val_output_dir)
# Out:
# Requirement already satisfied: matplotlib in ./newENV/lib/python3.12/site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./newENV/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./newENV/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./newENV/lib/python3.12/site-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./newENV/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in ./newENV/lib/python3.12/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in ./newENV/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in ./newENV/lib/python3.12/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./newENV/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./newENV/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./newENV/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# 2024-12-05 18:50:31.014408: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-05 18:50:31.108567: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733399431.160517    6956 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733399431.173924    6956 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-05 18:50:31.246443: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-05 18:50:33.315551: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# No faces detected in data/train/S407/S407-03-t10_02.ppm
# 2024-12-05 18:50:33.679512: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [0,48,48,3] vs. [1,1,1,32]
# Face saved to data-rev/train_crops/S399/face_1.ppm
# Face saved to data-rev/train_crops/S399/face_1.ppm
# Face saved to data-rev/train_crops/S399/face_1.ppm
# Face saved to data-rev/train_crops/S399/face_1.ppm
# Face saved to data-rev/train_crops/S412/face_1.ppm
# Face saved to data-rev/train_crops/S412/face_1.ppm
# Face saved to data-rev/train_crops/S418/face_1.ppm
# Face saved to data-rev/train_crops/S418/face_1.ppm
# Face saved to data-rev/train_crops/S413/face_1.ppm
# Face saved to data-rev/train_crops/S413/face_1.ppm
# Face saved to data-rev/train_crops/S413/face_1.ppm
# Face saved to data-rev/train_crops/S413/face_1.ppm
# Face saved to data-rev/train_crops/S413/face_1.ppm
# Face saved to data-rev/train_crops/S413/face_1.ppm
# Face saved to data-rev/train_crops/S405/face_1.ppm
# Face saved to data-rev/train_crops/S405/face_1.ppm
# Face saved to data-rev/train_crops/S405/face_1.ppm
# Face saved to data-rev/train_crops/S405/face_1.ppm
# Face saved to data-rev/train_crops/S415/face_1.ppm
# Face saved to data-rev/train_crops/S415/face_1.ppm
# Face saved to data-rev/train_crops/S415/face_1.ppm
# Face saved to data-rev/train_crops/S415/face_1.ppm
# Face saved to data-rev/train_crops/S415/face_1.ppm
# Face saved to data-rev/train_crops/S422/face_1.ppm
# Face saved to data-rev/train_crops/S422/face_1.ppm
# No faces detected in data/train/S422/S422-02-t10_01.ppm
# Face saved to data-rev/train_crops/S417/face_1.ppm
# Face saved to data-rev/train_crops/S417/face_1.ppm
# Face saved to data-rev/train_crops/S417/face_1.ppm
# Face saved to data-rev/train_crops/S417/face_1.ppm
# Face saved to data-rev/train_crops/S414/face_1.ppm
# Face saved to data-rev/train_crops/S414/face_1.ppm
# Face saved to data-rev/train_crops/S414/face_1.ppm
# Face saved to data-rev/train_crops/S414/face_1.ppm
# Face saved to data-rev/train_crops/S404/face_1.ppm
# Face saved to data-rev/train_crops/S404/face_1.ppm
# Face saved to data-rev/train_crops/S404/face_1.ppm
# Face saved to data-rev/train_crops/S404/face_1.ppm
# Face saved to data-rev/train_crops/S404/face_1.ppm
# Face saved to data-rev/train_crops/S404/face_1.ppm
# Face saved to data-rev/train_crops/S426/face_1.ppm
# Face saved to data-rev/train_crops/S401/face_1.ppm
# Face saved to data-rev/train_crops/S401/face_1.ppm
# Face saved to data-rev/train_crops/S401/face_1.ppm
# Face saved to data-rev/train_crops/S401/face_1.ppm
# Face saved to data-rev/train_crops/S401/face_1.ppm
# Face saved to data-rev/train_crops/S401/face_1.ppm
# Face saved to data-rev/train_crops/S420/face_1.ppm
# Face saved to data-rev/train_crops/S420/face_1.ppm
# Face saved to data-rev/train_crops/S420/face_1.ppm
# Face saved to data-rev/train_crops/S420/face_1.ppm
# No faces detected in data/train/S397/S397-02-t10_02.ppm
# 2024-12-05 18:50:46.505137: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [0,48,48,3] vs. [1,1,1,32]
# No faces detected in data/train/S397/S397-03-t10_02.ppm
# Face saved to data-rev/train_crops/S403/face_1.ppm
# Face saved to data-rev/train_crops/S403/face_1.ppm
# Face saved to data-rev/train_crops/S408/face_1.ppm
# No faces detected in data/train/S400/S400-03-t10_01.ppm
# Face saved to data-rev/train_crops/S400/face_1.ppm
# Face saved to data-rev/train_crops/S406/face_1.ppm
# Face saved to data-rev/train_crops/S398/face_1.ppm
# Face saved to data-rev/train_crops/S398/face_1.ppm
# Face saved to data-rev/train_crops/S411/face_1.ppm
# No faces detected in data/train/S411/S411-06-t10_03.ppm
# 2024-12-05 18:50:49.787452: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [0,48,48,3] vs. [1,1,1,32]
# Face saved to data-rev/train_crops/S411/face_1.ppm
# Face saved to data-rev/train_crops/S425/face_1.ppm
# Face saved to data-rev/train_crops/S425/face_1.ppm
# Face saved to data-rev/train_crops/S425/face_1.ppm
# Face saved to data-rev/train_crops/S428/face_1.ppm
# Face saved to data-rev/train_crops/S421/face_1.ppm
# Face saved to data-rev/train_crops/S419/face_1.ppm
# Face saved to data-rev/train_crops/S419/face_1.ppm
# Face saved to data-rev/train_crops/S419/face_1.ppm
# No faces detected in data/train/S419/S419-09-t10_01.ppm
# No faces detected in data/train/S419/S419-04-t10_01.ppm
# Face saved to data-rev/train_crops/S419/face_1.ppm
# Face saved to data-rev/train_crops/S402/face_1.ppm
# Face saved to data-rev/train_crops/S409/face_1.ppm
# Face saved to data-rev/train_crops/S409/face_1.ppm
# Face saved to data-rev/train_crops/S409/face_1.ppm
# No faces detected in data/train/S409/S409-09-t10_01.ppm
# Face saved to data-rev/train_crops/S409/face_1.ppm
# Face saved to data-rev/train_crops/S416/face_1.ppm
# Face saved to data-rev/train_crops/S388/face_1.ppm
# Face saved to data-rev/train_crops/S388/face_1.ppm
# Face saved to data-rev/train_crops/S388/face_1.ppm
# Face saved to data-rev/train_crops/S388/face_1.ppm
# Face saved to data-rev/train_crops/S388/face_1.ppm
# Face saved to data-rev/train_crops/S388/face_1.ppm
# Face saved to data-rev/train_crops/S388/face_1.ppm
# Face saved to data-rev/train_crops/S388/face_1.ppm
# Face saved to data-rev/train_crops/S388/face_1.ppm
# Face saved to data-rev/train_crops/S423/face_1.ppm
# Face saved to data-rev/train_crops/S423/face_1.ppm
# Face saved to data-rev/train_crops/S427/face_1.ppm
# Face saved to data-rev/train_crops/S429/face_1.ppm
# Face saved to data-rev/train_crops/S429/face_1.ppm
# Face saved to data-rev/train_crops/S429/face_1.ppm
# Face saved to data-rev/train_crops/S385/face_1.ppm
# Face saved to data-rev/train_crops/S346/face_1.ppm
# Face saved to data-rev/train_crops/S346/face_1.ppm
# Face saved to data-rev/train_crops/S394/face_1.ppm
# No faces detected in data/train/S394/S394-04-t10_01.ppm
# Face saved to data-rev/train_crops/S394/face_1.ppm
# Face saved to data-rev/train_crops/S394/face_1.ppm
# Face saved to data-rev/train_crops/S395/face_1.ppm
# Face saved to data-rev/train_crops/S390/face_1.ppm
# Face saved to data-rev/train_crops/S393/face_1.ppm
# Face saved to data-rev/train_crops/S389/face_1.ppm
# Face saved to data-rev/train_crops/S391/face_1.ppm
# Face saved to data-rev/train_crops/S396/face_1.ppm
# Face saved to data-rev/train_crops/S396/face_1.ppm
# Face saved to data-rev/train_crops/S396/face_1.ppm
# Face saved to data-rev/train_crops/S282/face_1.ppm
# Face saved to data-rev/train_crops/S282/face_1.ppm
# Face saved to data-rev/train_crops/S316/face_1.ppm
# Face saved to data-rev/train_crops/S316/face_1.ppm
# Face saved to data-rev/train_crops/S316/face_1.ppm
# Face saved to data-rev/train_crops/S316/face_1.ppm
# Face saved to data-rev/train_crops/S243/face_1.ppm
# Face saved to data-rev/train_crops/S243/face_1.ppm
# Face saved to data-rev/train_crops/S243/face_1.ppm
# No faces detected in data/train/S243/S243-09-t10_01.ppm
# Face saved to data-rev/train_crops/S243/face_1.ppm
# Face saved to data-rev/train_crops/S304/face_1.ppm
# Face saved to data-rev/train_crops/S335/face_1.ppm
# Face saved to data-rev/train_crops/S386/face_1.ppm
# Face saved to data-rev/train_crops/S386/face_1.ppm
# Face saved to data-rev/train_crops/S386/face_1.ppm
# Face saved to data-rev/train_crops/S386/face_1.ppm
# Face saved to data-rev/train_crops/S310/face_1.ppm
# Face saved to data-rev/train_crops/S310/face_1.ppm
# Face saved to data-rev/train_crops/S201/face_1.ppm
# Face saved to data-rev/train_crops/S201/face_1.ppm
# Face saved to data-rev/train_crops/S212/face_1.ppm
# Face saved to data-rev/train_crops/S212/face_1.ppm
# Face saved to data-rev/train_crops/S383/face_1.ppm
# Face saved to data-rev/train_crops/S297/face_1.ppm
# No faces detected in data/train/S364/S364-02-t10_01.ppm
# 2024-12-05 18:51:08.505786: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [0,24,24,3] vs. [1,1,1,28]
# Face saved to data-rev/train_crops/S153/face_1.ppm
# Face saved to data-rev/train_crops/S195/face_1.ppm
# Face saved to data-rev/train_crops/S195/face_1.ppm
# Face saved to data-rev/train_crops/S195/face_1.ppm
# Face saved to data-rev/train_crops/S300/face_1.ppm
# Face saved to data-rev/train_crops/S392/face_1.ppm
# Face saved to data-rev/train_crops/S392/face_1.ppm
# Face saved to data-rev/train_crops/S392/face_1.ppm
# Face saved to data-rev/train_crops/S215/face_1.ppm
# Face saved to data-rev/train_crops/S355/face_1.ppm
# Face saved to data-rev/train_crops/S199/face_1.ppm
# Face saved to data-rev/train_crops/S387/face_1.ppm
# Face saved to data-rev/train_crops/S387/face_1.ppm
# No faces detected in data/train/S315/S315-01-t10_02.ppm
# Face saved to data-rev/train_crops/S315/face_1.ppm
# Face saved to data-rev/train_crops/S373/face_1.ppm
# Face saved to data-rev/train_crops/S373/face_1.ppm
# Face saved to data-rev/train_crops/S373/face_1.ppm
# Face saved to data-rev/train_crops/S273/face_1.ppm
# Face saved to data-rev/train_crops/S273/face_1.ppm
# Face saved to data-rev/train_crops/S273/face_1.ppm
# Face saved to data-rev/train_crops/S206/face_1.ppm
# Face saved to data-rev/train_crops/S288/face_1.ppm
# Face saved to data-rev/train_crops/S331/face_1.ppm
# Face saved to data-rev/train_crops/S194/face_1.ppm
# Face saved to data-rev/train_crops/S226/face_1.ppm
# Face saved to data-rev/train_crops/S333/face_1.ppm
# Face saved to data-rev/train_crops/S220/face_1.ppm
# Face saved to data-rev/train_crops/S272/face_1.ppm
# Face saved to data-rev/train_crops/S272/face_1.ppm
# Face saved to data-rev/train_crops/S353/face_1.ppm
# Face saved to data-rev/train_crops/S353/face_1.ppm
# No faces detected in data/train/S353/S353-02-t10_01.ppm
# Face saved to data-rev/train_crops/S353/face_1.ppm
# No faces detected in data/train/S353/S353-03-t10_01.ppm
# Face saved to data-rev/train_crops/S353/face_1.ppm
# No faces detected in data/train/S198/S198-04-t10_01.ppm
# Face saved to data-rev/train_crops/S198/face_1.ppm
# Face saved to data-rev/train_crops/S174/face_1.ppm
# Face saved to data-rev/train_crops/S174/face_1.ppm
# Face saved to data-rev/train_crops/S223/face_1.ppm
# Face saved to data-rev/train_crops/S223/face_1.ppm
# No faces detected in data/train/S381/S381-02-t10_01.ppm
# Face saved to data-rev/train_crops/S296/face_1.ppm
# Face saved to data-rev/train_crops/S296/face_1.ppm
# Face saved to data-rev/train_crops/S296/face_1.ppm
# Face saved to data-rev/train_crops/S296/face_1.ppm
# Face saved to data-rev/train_crops/S296/face_1.ppm
# Face saved to data-rev/train_crops/S296/face_1.ppm
# Face saved to data-rev/train_crops/S296/face_1.ppm
# Face saved to data-rev/train_crops/S296/face_1.ppm
# Face saved to data-rev/train_crops/S382/face_1.ppm
# Face saved to data-rev/train_crops/S382/face_1.ppm
# Face saved to data-rev/train_crops/S382/face_1.ppm
# Face saved to data-rev/train_crops/S341/face_1.ppm
# Face saved to data-rev/train_crops/S227/face_1.ppm
# No faces detected in data/train/S283/S283-01-t10_01.ppm
# Face saved to data-rev/train_crops/S239/face_1.ppm
# Face saved to data-rev/train_crops/S222/face_1.ppm
# No faces detected in data/train/S350/S350-02-t10_01.ppm
# Face saved to data-rev/train_crops/S357/face_1.ppm
# No faces detected in data/train/S295/S295-01-t10_02.ppm
# Face saved to data-rev/train_crops/S352/face_1.ppm
# Face saved to data-rev/train_crops/S352/face_1.ppm
# Face saved to data-rev/train_crops/S166/face_1.ppm
# No faces detected in data/train/S166/S166-02-t10_02.ppm
# 2024-12-05 18:51:24.998940: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [0,48,48,3] vs. [1,1,1,32]
# Face saved to data-rev/train_crops/S380/face_1.ppm
# Face saved to data-rev/train_crops/S380/face_1.ppm
# No faces detected in data/train/S380/S380-03-t10_01.ppm
# Face saved to data-rev/train_crops/S375/face_1.ppm
# Face saved to data-rev/train_crops/S351/face_1.ppm
# Face saved to data-rev/train_crops/S367/face_1.ppm
# Face saved to data-rev/train_crops/S214/face_1.ppm
# Face saved to data-rev/train_crops/S214/face_1.ppm
# Face saved to data-rev/train_crops/S254/face_1.ppm
# Face saved to data-rev/train_crops/S254/face_1.ppm
# Face saved to data-rev/train_crops/S258/face_1.ppm
# Face saved to data-rev/train_crops/S376/face_1.ppm
# Face saved to data-rev/train_crops/S132/face_1.ppm
# Face saved to data-rev/train_crops/S354/face_1.ppm
# Face saved to data-rev/train_crops/S325/face_1.ppm
# Face saved to data-rev/train_crops/S148/face_1.ppm
# No faces detected in data/train/S148/S148-04-t10_01.ppm
# Face saved to data-rev/train_crops/S148/face_1.ppm
# Face saved to data-rev/train_crops/S384/face_1.ppm
# Face saved to data-rev/train_crops/S232/face_1.ppm
# Face saved to data-rev/train_crops/S270/face_1.ppm
# Face saved to data-rev/train_crops/S228/face_1.ppm
# No faces detected in data/train/S228/S228-03-t10_01.ppm
# Face saved to data-rev/train_crops/S313/face_1.ppm
# Face saved to data-rev/train_crops/S324/face_1.ppm
# Face saved to data-rev/train_crops/S253/face_1.ppm
# Face saved to data-rev/train_crops/S253/face_1.ppm
# No faces detected in data/train/S321/S321-03-t10_02.ppm
# Face saved to data-rev/train_crops/S250/face_1.ppm
# Face saved to data-rev/train_crops/S280/face_1.ppm
# Face saved to data-rev/train_crops/S280/face_1.ppm
# Face saved to data-rev/train_crops/S280/face_1.ppm
# Face saved to data-rev/train_crops/S280/face_1.ppm
# No faces detected in data/train/S284/S284-02-t10_02.ppm
# Face saved to data-rev/train_crops/S284/face_1.ppm
# Face saved to data-rev/train_crops/S191/face_1.ppm
# Face saved to data-rev/train_crops/S203/face_1.ppm
# No faces detected in data/train/S203/S203-01-t10_02.ppm
# Face saved to data-rev/train_crops/S285/face_1.ppm
# No faces detected in data/train/S180/S180-01-t10_02.ppm
# Face saved to data-rev/train_crops/S202/face_1.ppm
# Face saved to data-rev/train_crops/S202/face_1.ppm
# Face saved to data-rev/train_crops/S202/face_1.ppm
# Face saved to data-rev/train_crops/S336/face_1.ppm
# Face saved to data-rev/train_crops/S219/face_1.ppm
# Face saved to data-rev/train_crops/S219/face_1.ppm
# Face saved to data-rev/train_crops/S236/face_1.ppm
# Face saved to data-rev/train_crops/S291/face_1.ppm
# Face saved to data-rev/train_crops/S193/face_1.ppm
# Face saved to data-rev/train_crops/S142/face_1.ppm
# Face saved to data-rev/train_crops/S142/face_1.ppm
# Face saved to data-rev/train_crops/S142/face_1.ppm
# Face saved to data-rev/train_crops/S130/face_1.ppm
# Face saved to data-rev/train_crops/S182/face_1.ppm
# No faces detected in data/train/S182/S182-02-t10_02.ppm
# Face saved to data-rev/train_crops/S173/face_1.ppm
# Face saved to data-rev/train_crops/S261/face_1.ppm
# Face saved to data-rev/train_crops/S240/face_1.ppm
# Face saved to data-rev/train_crops/S307/face_1.ppm
# Face saved to data-rev/train_crops/S309/face_1.ppm
# Face saved to data-rev/train_crops/S309/face_1.ppm
# Face saved to data-rev/train_crops/S309/face_1.ppm
# Face saved to data-rev/train_crops/S309/face_1.ppm
# Face saved to data-rev/train_crops/S256/face_1.ppm
# Face saved to data-rev/train_crops/S263/face_1.ppm
# Face saved to data-rev/train_crops/S190/face_1.ppm
# Face saved to data-rev/train_crops/S171/face_1.ppm
# Face saved to data-rev/train_crops/S171/face_1.ppm
# Face saved to data-rev/train_crops/S171/face_1.ppm
# Face saved to data-rev/train_crops/S171/face_1.ppm
# No faces detected in data/train/S171/S171-02-t10_01.ppm
# Face saved to data-rev/train_crops/S171/face_1.ppm
# Face saved to data-rev/train_crops/S171/face_1.ppm
# Face saved to data-rev/train_crops/S259/face_1.ppm
# No faces detected in data/train/S164/S164-02-t10_02.ppm
# Face saved to data-rev/train_crops/S164/face_1.ppm
# Face saved to data-rev/train_crops/S118/face_1.ppm
# Face saved to data-rev/train_crops/S118/face_1.ppm
# Face saved to data-rev/train_crops/S249/face_1.ppm
# Face saved to data-rev/train_crops/S146/face_1.ppm
# Face saved to data-rev/train_crops/S096/face_1.ppm
# Face saved to data-rev/train_crops/S225/face_1.ppm
# Face saved to data-rev/train_crops/S185/face_1.ppm
# Face saved to data-rev/train_crops/S185/face_1.ppm
# Face saved to data-rev/train_crops/S185/face_1.ppm
# Face saved to data-rev/train_crops/S150/face_1.ppm
# Face saved to data-rev/train_crops/S124/face_1.ppm
# Face saved to data-rev/train_crops/S134/face_1.ppm
# Face saved to data-rev/train_crops/S134/face_1.ppm
# Face saved to data-rev/train_crops/S134/face_1.ppm
# Face saved to data-rev/train_crops/S134/face_1.ppm
# Face saved to data-rev/train_crops/S134/face_1.ppm
# Face saved to data-rev/train_crops/S138/face_1.ppm
# Face saved to data-rev/train_crops/S059/face_1.ppm
# Face saved to data-rev/train_crops/S111/face_1.ppm
# Face saved to data-rev/train_crops/S111/face_1.ppm
# Face saved to data-rev/train_crops/S111/face_1.ppm
# Face saved to data-rev/train_crops/S111/face_1.ppm
# Face saved to data-rev/train_crops/S098/face_1.ppm
# Face saved to data-rev/train_crops/S163/face_1.ppm
# Face saved to data-rev/train_crops/S095/face_1.ppm
# Face saved to data-rev/train_crops/S112/face_1.ppm
# No faces detected in data/train/S120/S120-01-t10_02.ppm
# Face saved to data-rev/train_crops/S046/face_1.ppm
# Face saved to data-rev/train_crops/S085/face_1.ppm
# No faces detected in data/train/S085/S085-01-t10_02.ppm
# Face saved to data-rev/train_crops/S033/face_1.ppm
# Face saved to data-rev/train_crops/S033/face_1.ppm
# No faces detected in data/train/S033/S033-01-t10_01.ppm
# Face saved to data-rev/train_crops/S033/face_1.ppm
# Face saved to data-rev/train_crops/S033/face_1.ppm
# Face saved to data-rev/train_crops/S033/face_1.ppm
# Face saved to data-rev/train_crops/S065/face_1.ppm
# Face saved to data-rev/train_crops/S099/face_1.ppm
# Face saved to data-rev/train_crops/S133/face_1.ppm
# Face saved to data-rev/train_crops/S133/face_1.ppm
# Face saved to data-rev/train_crops/S073/face_1.ppm
# Face saved to data-rev/train_crops/S076/face_1.ppm
# Face saved to data-rev/train_crops/S051/face_1.ppm
# Face saved to data-rev/train_crops/S088/face_1.ppm
# No faces detected in data/train/S145/S145-01-t10_02.ppm
# Face saved to data-rev/train_crops/S108/face_1.ppm
# Face saved to data-rev/train_crops/S108/face_1.ppm
# No faces detected in data/train/S108/S108-03-t10_01.ppm
# Face saved to data-rev/train_crops/S117/face_1.ppm
# Face saved to data-rev/train_crops/S054/face_1.ppm
# Face saved to data-rev/train_crops/S054/face_1.ppm
# Face saved to data-rev/train_crops/S078/face_1.ppm
# No faces detected in data/train/S078/S078-02-t10_02.ppm
# Face saved to data-rev/train_crops/S078/face_1.ppm
# Face saved to data-rev/train_crops/S032/face_1.ppm
# No faces detected in data/train/S032/S032-03-t10_01.ppm
# Face saved to data-rev/train_crops/S101/face_1.ppm
# No faces detected in data/train/S044/S044-03-t10_01.ppm
# No faces detected in data/train/S044/S044-08-t10_01.ppm
# No faces detected in data/train/S044/S044-09-t10_01.ppm
# 2024-12-05 18:52:00.057783: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [0,48,48,3] vs. [1,1,1,32]
# No faces detected in data/train/S044/S044-01-t10_01.ppm
# No faces detected in data/train/S044/S044-02-t10_01.ppm
# Face saved to data-rev/train_crops/S044/face_1.ppm
# No faces detected in data/train/S044/S044-06-t10_01.ppm
# Face saved to data-rev/train_crops/S058/face_1.ppm
# Face saved to data-rev/train_crops/S058/face_1.ppm
# Face saved to data-rev/train_crops/S068/face_1.ppm
# Face saved to data-rev/train_crops/S068/face_1.ppm
# Face saved to data-rev/train_crops/S068/face_1.ppm
# Face saved to data-rev/train_crops/S052/face_1.ppm
# Face saved to data-rev/train_crops/S001/face_1.ppm
# Face saved to data-rev/train_crops/S001/face_1.ppm
# Face saved to data-rev/train_crops/S001/face_1.ppm
# Face saved to data-rev/train_crops/S001/face_1.ppm
# Face saved to data-rev/train_crops/S001/face_1.ppm
# Face saved to data-rev/train_crops/S001/face_1.ppm
# Face saved to data-rev/train_crops/S001/face_1.ppm
# Face saved to data-rev/train_crops/S001/face_1.ppm
# Face saved to data-rev/train_crops/S064/face_1.ppm
# No faces detected in data/train/S093/S093-01-t10_01.ppm
# No faces detected in data/train/S045/S045-01-t10_02.ppm
# Face saved to data-rev/train_crops/S069/face_1.ppm
# Face saved to data-rev/train_crops/S036/face_1.ppm
# Face saved to data-rev/train_crops/S036/face_1.ppm
# No faces detected in data/train/S006/S006-02-t10_01.ppm
# Face saved to data-rev/train_crops/S006/face_1.ppm
# Face saved to data-rev/train_crops/S048/face_1.ppm
# Face saved to data-rev/train_crops/S048/face_1.ppm
# Face saved to data-rev/train_crops/S048/face_1.ppm
# Face saved to data-rev/train_crops/S048/face_1.ppm
# Face saved to data-rev/train_crops/S048/face_1.ppm
# Face saved to data-rev/train_crops/S015/face_1.ppm
# No faces detected in data/train/S015/S015-01-t10_01.ppm
# Face saved to data-rev/train_crops/S008/face_1.ppm
# Face saved to data-rev/train_crops/S008/face_1.ppm
# Face saved to data-rev/train_crops/S008/face_1.ppm
# Face saved to data-rev/train_crops/S008/face_1.ppm
# Face saved to data-rev/train_crops/S008/face_1.ppm
# No faces detected in data/train/S008/S008-05-t10_01.ppm
# Face saved to data-rev/train_crops/S031/face_1.ppm
# Face saved to data-rev/train_crops/S031/face_1.ppm
# Face saved to data-rev/train_crops/S031/face_1.ppm
# Face saved to data-rev/train_crops/S031/face_1.ppm
# Face saved to data-rev/train_crops/S030/face_1.ppm
# Face saved to data-rev/train_crops/S030/face_1.ppm
# Face saved to data-rev/train_crops/S030/face_1.ppm
# Face saved to data-rev/train_crops/S023/face_1.ppm
# Face saved to data-rev/train_crops/S023/face_1.ppm
# Face saved to data-rev/train_crops/S013/face_1.ppm
# Face saved to data-rev/train_crops/S027/face_1.ppm
# Face saved to data-rev/train_crops/S022/face_1.ppm
# Face saved to data-rev/train_crops/S029/face_1.ppm
# Face saved to data-rev/val_crops/S429/face_1.ppm
# Face saved to data-rev/val_crops/S414/face_1.ppm
# Face saved to data-rev/val_crops/S414/face_1.ppm
# No faces detected in data/val/S414/S414-10-t10_01.ppm
# Face saved to data-rev/val_crops/S414/face_1.ppm
# Face saved to data-rev/val_crops/S414/face_1.ppm
# Face saved to data-rev/val_crops/S414/face_1.ppm
# Face saved to data-rev/val_crops/S414/face_1.ppm
# Face saved to data-rev/val_crops/S006/face_1.ppm
# Face saved to data-rev/val_crops/S036/face_1.ppm
# Face saved to data-rev/val_crops/S054/face_1.ppm
# Face saved to data-rev/val_crops/S099/face_1.ppm
# Face saved to data-rev/val_crops/S099/face_1.ppm
# Face saved to data-rev/val_crops/S095/face_1.ppm
# Face saved to data-rev/val_crops/S163/face_1.ppm
# Face saved to data-rev/val_crops/S133/face_1.ppm
# Face saved to data-rev/val_crops/S048/face_1.ppm
# Face saved to data-rev/val_crops/S048/face_1.ppm
# Face saved to data-rev/val_crops/S046/face_1.ppm
# Face saved to data-rev/val_crops/S101/face_1.ppm
# No faces detected in data/val/S059/S059-01-t10_02.ppm
# Face saved to data-rev/val_crops/S013/face_1.ppm
# Face saved to data-rev/val_crops/S166/face_1.ppm
# Face saved to data-rev/val_crops/S008/face_1.ppm
# No faces detected in data/val/S148/S148-01-t10_01.ppm
# Face saved to data-rev/val_crops/S111/face_1.ppm
# Face saved to data-rev/val_crops/S032/face_1.ppm
# Face saved to data-rev/val_crops/S032/face_2.ppm
# Face saved to data-rev/val_crops/S112/face_1.ppm
# Face saved to data-rev/val_crops/S134/face_1.ppm
# Face saved to data-rev/val_crops/S134/face_1.ppm
# Face saved to data-rev/val_crops/S134/face_1.ppm
# Face saved to data-rev/val_crops/S130/face_1.ppm
# Face saved to data-rev/val_crops/S145/face_1.ppm
# Face saved to data-rev/val_crops/S073/face_1.ppm
# Face saved to data-rev/val_crops/S045/face_1.ppm
# Face saved to data-rev/val_crops/S212/face_1.ppm
# Face saved to data-rev/val_crops/S258/face_1.ppm
# Face saved to data-rev/val_crops/S093/face_1.ppm
# Face saved to data-rev/val_crops/S250/face_1.ppm
# Face saved to data-rev/val_crops/S180/face_1.ppm
# Face saved to data-rev/val_crops/S015/face_1.ppm
# Face saved to data-rev/val_crops/S226/face_1.ppm
# Face saved to data-rev/val_crops/S253/face_1.ppm
# Face saved to data-rev/val_crops/S253/face_1.ppm
# Face saved to data-rev/val_crops/S383/face_1.ppm
# Face saved to data-rev/val_crops/S194/face_1.ppm
# Face saved to data-rev/val_crops/S386/face_1.ppm
# Face saved to data-rev/val_crops/S386/face_1.ppm
# Face saved to data-rev/val_crops/S386/face_1.ppm
# Face saved to data-rev/val_crops/S386/face_1.ppm
# Face saved to data-rev/val_crops/S078/face_1.ppm
# Face saved to data-rev/val_crops/S078/face_1.ppm
# Face saved to data-rev/val_crops/S256/face_1.ppm
# Face saved to data-rev/val_crops/S399/face_1.ppm
# Face saved to data-rev/val_crops/S399/face_1.ppm
# Face saved to data-rev/val_crops/S336/face_1.ppm
# Face saved to data-rev/val_crops/S376/face_1.ppm
# Face saved to data-rev/val_crops/S376/face_1.ppm
# Face saved to data-rev/val_crops/S387/face_1.ppm
# Face saved to data-rev/val_crops/S195/face_1.ppm
# Face saved to data-rev/val_crops/S381/face_1.ppm
# Face saved to data-rev/val_crops/S393/face_1.ppm
# No faces detected in data/val/S393/S393-03-t10_01.ppm
# No faces detected in data/val/S393/S393-02-t10_01.ppm
# Face saved to data-rev/val_crops/S388/face_1.ppm
# Face saved to data-rev/val_crops/S388/face_1.ppm
# Face saved to data-rev/val_crops/S388/face_1.ppm
# Face saved to data-rev/val_crops/S388/face_1.ppm
# Face saved to data-rev/val_crops/S388/face_1.ppm
# Face saved to data-rev/val_crops/S388/face_1.ppm
# Face saved to data-rev/val_crops/S388/face_1.ppm
# Face saved to data-rev/val_crops/S388/face_1.ppm
# Face saved to data-rev/val_crops/S388/face_1.ppm
# Face saved to data-rev/val_crops/S202/face_1.ppm
# Face saved to data-rev/val_crops/S350/face_1.ppm
# Face saved to data-rev/val_crops/S304/face_1.ppm
# Face saved to data-rev/val_crops/S304/face_1.ppm
# Face saved to data-rev/val_crops/S384/face_1.ppm
# Face saved to data-rev/val_crops/S309/face_1.ppm
# No faces detected in data/val/S283/S283-02-t10_01.ppm
# Face saved to data-rev/val_crops/S395/face_1.ppm
# Face saved to data-rev/val_crops/S382/face_1.ppm
# Face saved to data-rev/val_crops/S382/face_1.ppm
# Face saved to data-rev/val_crops/S382/face_1.ppm
# Face saved to data-rev/val_crops/S382/face_1.ppm
# Face saved to data-rev/val_crops/S382/face_1.ppm
# Face saved to data-rev/val_crops/S382/face_1.ppm
# Face saved to data-rev/val_crops/S382/face_1.ppm
# Face saved to data-rev/val_crops/S273/face_1.ppm
# Face saved to data-rev/val_crops/S273/face_1.ppm
# No faces detected in data/val/S173/S173-01-t10_01.ppm
# Face saved to data-rev/val_crops/S373/face_1.ppm
# Face saved to data-rev/val_crops/S373/face_1.ppm
# Face saved to data-rev/val_crops/S373/face_1.ppm
# Face saved to data-rev/val_crops/S385/face_1.ppm
# Face saved to data-rev/val_crops/S219/face_1.ppm
# Face saved to data-rev/val_crops/S316/face_1.ppm
# Face saved to data-rev/val_crops/S316/face_1.ppm
# Face saved to data-rev/val_crops/S316/face_1.ppm
# No faces detected in data/val/S316/S316-02-t10_01.ppm
# Face saved to data-rev/val_crops/S138/face_1.ppm
# Face saved to data-rev/val_crops/S341/face_1.ppm
# Face saved to data-rev/val_crops/S353/face_1.ppm
# No faces detected in data/val/S353/S353-05-t10_01.ppm
# Face saved to data-rev/val_crops/S243/face_1.ppm
# Face saved to data-rev/val_crops/S243/face_1.ppm
# Face saved to data-rev/val_crops/S243/face_1.ppm
# Face saved to data-rev/val_crops/S243/face_1.ppm
# Face saved to data-rev/val_crops/S380/face_1.ppm
# Face saved to data-rev/val_crops/S380/face_1.ppm
# Face saved to data-rev/val_crops/S380/face_1.ppm
# Face saved to data-rev/val_crops/S380/face_1.ppm
# Face saved to data-rev/val_crops/S357/face_1.ppm
# Face saved to data-rev/val_crops/S270/face_1.ppm
# Face saved to data-rev/val_crops/S272/face_1.ppm
# Face saved to data-rev/val_crops/S364/face_1.ppm
# Face saved to data-rev/val_crops/S392/face_1.ppm
# Face saved to data-rev/val_crops/S392/face_1.ppm
# Face saved to data-rev/val_crops/S392/face_1.ppm
# Face saved to data-rev/val_crops/S392/face_1.ppm
# Face saved to data-rev/val_crops/S392/face_1.ppm
# Face saved to data-rev/val_crops/S367/face_1.ppm
# Face saved to data-rev/val_crops/S288/face_1.ppm
# Face saved to data-rev/val_crops/S288/face_1.ppm
# Face saved to data-rev/val_crops/S288/face_1.ppm
# Face saved to data-rev/val_crops/S288/face_1.ppm
# Face saved to data-rev/val_crops/S354/face_1.ppm
# Face saved to data-rev/val_crops/S354/face_1.ppm
# Face saved to data-rev/val_crops/S354/face_1.ppm
# No faces detected in data/val/S391/S391-03-t10_01.ppm
# 2024-12-05 18:53:22.372149: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [0,48,48,3] vs. [1,1,1,32]
# Face saved to data-rev/val_crops/S391/face_1.ppm
# Face saved to data-rev/val_crops/S261/face_1.ppm
# Face saved to data-rev/val_crops/S351/face_1.ppm
# Face saved to data-rev/val_crops/S310/face_1.ppm
# Face saved to data-rev/val_crops/S310/face_1.ppm
# Face saved to data-rev/val_crops/S282/face_1.ppm
# Face saved to data-rev/val_crops/S375/face_1.ppm
# Face saved to data-rev/val_crops/S355/face_1.ppm
# Face saved to data-rev/val_crops/S346/face_1.ppm
# Face saved to data-rev/val_crops/S284/face_1.ppm
# No faces detected in data/val/S284/S284-01-t10_02.ppm
# No faces detected in data/val/S307/S307-01-t10_02.ppm
# Face saved to data-rev/val_crops/S280/face_1.ppm
# Face saved to data-rev/val_crops/S280/face_1.ppm
# Face saved to data-rev/val_crops/S280/face_1.ppm
# Face saved to data-rev/val_crops/S280/face_1.ppm
# Face saved to data-rev/val_crops/S280/face_1.ppm
# Face saved to data-rev/val_crops/S280/face_1.ppm
# Face saved to data-rev/val_crops/S335/face_1.ppm
# Face saved to data-rev/val_crops/S335/face_2.ppm
# Face saved to data-rev/val_crops/S098/face_1.ppm
# Face saved to data-rev/val_crops/S390/face_1.ppm
# Face saved to data-rev/val_crops/S394/face_1.ppm
# Face saved to data-rev/val_crops/S331/face_1.ppm
# Face saved to data-rev/val_crops/S300/face_1.ppm
# Face saved to data-rev/val_crops/S321/face_1.ppm
# Face saved to data-rev/val_crops/S321/face_1.ppm
# Face saved to data-rev/val_crops/S321/face_1.ppm
# Face saved to data-rev/val_crops/S313/face_1.ppm
# No faces detected in data/val/S291/S291-02-t10_01.ppm
# No faces detected in data/val/S325/S325-01-t10_02.ppm
# Face saved to data-rev/val_crops/S297/face_1.ppm
# Face saved to data-rev/val_crops/S324/face_1.ppm
# Face saved to data-rev/val_crops/S296/face_1.ppm
# Face saved to data-rev/val_crops/S296/face_1.ppm
# No faces detected in data/val/S263/S263-01-t10_02.ppm
# Face saved to data-rev/val_crops/S285/face_1.ppm
# Face saved to data-rev/val_crops/S389/face_1.ppm
# Face saved to data-rev/val_crops/S239/face_1.ppm
# Face saved to data-rev/val_crops/S333/face_1.ppm
# Face saved to data-rev/val_crops/S315/face_1.ppm
# No faces detected in data/val/S315/S315-02-t10_02.ppm
# Face saved to data-rev/val_crops/S295/face_1.ppm

# %%
import os
import random
import cv2
import numpy as np
from mtcnn import MTCNN
import matplotlib.pyplot as plt

# Fungsi untuk menyesuaikan kecerahan gambar
def adjust_brightness(image, factor=1.2):
    """Adjust brightness by scaling the pixel values."""
    hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
    hsv[:,:,2] = np.clip(hsv[:,:,2] * factor, 0, 255)
    return cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)

# Fungsi untuk mengubah gambar menjadi grayscale
def to_grayscale(image):
    """Convert image to grayscale."""
    return cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# Fungsi untuk menggeser gambar secara acak
def shift_image(image, max_shift=10):
    """Shift image randomly in x and y direction."""
    M = np.float32([[1, 0, random.randint(-max_shift, max_shift)], [0, 1, random.randint(-max_shift, max_shift)]])
    return cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))

# Fungsi untuk memflip gambar secara horizontal
def flip_image(image):
    """Flip image horizontally."""
    return cv2.flip(image, 1)

# Fungsi untuk mendeteksi wajah dan menyimpan hasil crop wajah beserta augmentasi
def save_face_crop(image_path, output_folder):
    detector = MTCNN()

    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Ubah ke RGB untuk matplotlib

    faces = detector.detect_faces(img)

    if faces:
        for i, face in enumerate(faces):
            x1, y1, width, height = face['box']
            x2, y2 = x1 + width, y1 + height
            cropped_face = img[y1:y2, x1:x2]

            # Apply augmentations
            cropped_face_brightness = adjust_brightness(cropped_face)
            cropped_face_gray = to_grayscale(cropped_face)
            cropped_face_shifted = shift_image(cropped_face)
            cropped_face_flipped = flip_image(cropped_face)

            # Membuat folder output jika belum ada
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)

            # Menyimpan gambar yang teraugmentasi
            augmentations = [
                ('brightness', cropped_face_brightness),
                ('grayscale', cropped_face_gray),
                ('shifted', cropped_face_shifted),
                ('flipped', cropped_face_flipped)
            ]
            
            for augment_name, augmented_image in augmentations:
                file_name = f"face_{i+1}_{augment_name}.ppm"
                output_path = os.path.join(output_folder, file_name)
                
                if augmented_image.ndim == 2:  # Jika gambar grayscale, ubah menjadi 3 channel untuk penyimpanan
                    augmented_image = cv2.cvtColor(augmented_image, cv2.COLOR_GRAY2RGB)

                cv2.imwrite(output_path, augmented_image)
                print(f"Augmented face saved to {output_path}")
    else:
        print(f"No faces detected in {image_path}")

# Fungsi untuk memproses seluruh gambar dalam direktori
def process_directory(input_dir, output_dir):
    for class_folder in os.listdir(input_dir):
        class_path = os.path.join(input_dir, class_folder)
        
        # Periksa apakah itu folder dan bukan file
        if os.path.isdir(class_path):
            class_output_dir = os.path.join(output_dir, class_folder)
            
            for image_file in os.listdir(class_path):
                image_path = os.path.join(class_path, image_file)
                
                # Periksa apakah file berformat ppm
                if image_file.endswith('.ppm'):
                    save_face_crop(image_path, class_output_dir)

# Path direktori training dan validation
train_dir = 'data/train/'
val_dir = 'data/val/'

# Path output untuk hasil crop wajah
train_output_dir = 'data/train_crops/'
val_output_dir = 'data/val_crops/'

# Proses seluruh gambar dalam direktori train dan val
process_directory(train_dir, train_output_dir)
process_directory(val_dir, val_output_dir)
# Out:
# No faces detected in data/train/S407/S407-03-t10_02.ppm
# Augmented face saved to data-rev/train_crops/
class DlibFeatureExtractor:
    def __init__(self, 
                 shape_predictor_path='dat/shape_predictor_68_face_landmarks.dat',
                 face_rec_model_path='dat/dlib_face_recognition_resnet_model_v1.dat'):
        """
        Initialize dlib face detector, shape predictor, and face recognition model.
        
        Args:
            shape_predictor_path (str): Path to shape predictor model file.
            face_rec_model_path (str): Path to face recognition model file.
        """
        self.detector = dlib.get_frontal_face_detector()
        self.shape_predictor = dlib.shape_predictor(shape_predictor_path)
        self.face_rec_model = dlib.face_recognition_model_v1(face_rec_model_path)
    
    def extract_features(self, image_path):
        """
        Detect faces and extract 128D feature vectors using dlib.
        
        Args:
            image_path (str): Path to the input image.
        
        Returns:
            list: List of feature vectors (one per face) or empty list if no faces are detected.
        """
        try:
            # Read the image
            image = cv2.imread(image_path)
            if image is None:
                print(f"Error: Unable to read image {image_path}")
                return []

            # Resize the image (optional for better face detection)
            image_resized = cv2.resize(image, (800, 800))

            # Convert image from BGR to RGB (dlib uses RGB)
            rgb_image = cv2.cvtColor(image_resized, cv2.COLOR_BGR2RGB)
            
            # Detect faces in the image
            faces = self.detector(rgb_image, upsample_num_times=2)  # Increase sensitivity by upsampling
            if len(faces) == 0:
                print(f"Warning: No faces detected in image {image_path}")
            
            features = []
            
            # Extract features for each detected face
            for face in faces:
                # Predict landmarks
                shape = self.shape_predictor(rgb_image, face)
                
                # Compute 128D face descriptor
                face_descriptor = self.face_rec_model.compute_face_descriptor(rgb_image, shape)
                
                # Append to features
                features.append(np.array(face_descriptor))
            
            return features
        except Exception as e:
            print(f"Error processing {image_path}: {e}")
            return []

    def extract_and_save_features(self, dataset_root, output_train, output_val):
        """
        Extract features for train and val datasets, and save to .npz files.
        
        Args:
            dataset_root (str): Root directory of the dataset.
            output_train (str): Path to save train features in .npz format.
            output_val (str): Path to save validation features in .npz format.
        """
        features_train, labels_train = [], []
        features_val, labels_val = [], []

        for split in ['train_crops', 'val_crops']:  # Correct split names
            split_path = os.path.join(dataset_root, split)
            for subject in os.listdir(split_path):
                subject_path = os.path.join(split_path, subject)
                for image_file in os.listdir(subject_path):
                    if image_file.lower().endswith('.ppm'):
                        image_path = os.path.join(subject_path, image_file)
                        try:
                            # Extract features for faces in the image
                            extracted_features = self.extract_features(image_path)
                            
                            # Skip empty features list (no faces detected)
                            if not extracted_features:
                                print(f"Skipping {image_path} due to missing features")
                                continue

                            # Append features and labels to corresponding lists
                            for feature in extracted_features:
                                if split == 'train_crops':  # Correct split name
                                    features_train.append(feature)
                                    labels_train.append(subject)
                                elif split == 'val_crops':  # Correct split name
                                    features_val.append(feature)
                                    labels_val.append(subject)
                        except Exception as e:
                            print(f"Error processing {image_path}: {e}")

        # Save to .npz files only if features are extracted
        if features_train and labels_train:
            np.savez_compressed(output_train, features=np.array(features_train), labels=np.array(labels_train))
            print(f"Training data saved to {output_train}")
        else:
            print("No training features to save!")

        if features_val and labels_val:
            np.savez_compressed(output_val, features=np.array(features_val), labels=np.array(labels_val))
            print(f"Validation data saved to {output_val}")
        else:
            print("No validation features to save!")

# Example usage
dataset_root = 'data'
output_train = 'npz/train.npz'
output_val = 'npz/val.npz'

# Initialize feature extractor
extractor = DlibFeatureExtractor(
    shape_predictor_path='dat/shape_predictor_68_face_landmarks.dat',
    face_rec_model_path='dat/dlib_face_recognition_resnet_model_v1.dat'
)

# Extract and save features
extractor.extract_and_save_features(dataset_root, output_train, output_val)
# Out:
# Warning: No faces detected in image data/train_crops/S413/face_1.ppm
# Skipping data/train_crops/S413/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S413/face_1_brightness.ppm
# Skipping data/train_crops/S413/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S413/face_1_grayscale.ppm
# Skipping data/train_crops/S413/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S413/face_1_flipped.ppm
# Skipping data/train_crops/S413/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S422/face_1.ppm
# Skipping data/train_crops/S422/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S422/face_1_brightness.ppm
# Skipping data/train_crops/S422/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S422/face_1_grayscale.ppm
# Skipping data/train_crops/S422/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S422/face_1_flipped.ppm
# Skipping data/train_crops/S422/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S426/face_1_flipped.ppm
# Skipping data/train_crops/S426/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S411/face_1_shifted.ppm
# Skipping data/train_crops/S411/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S421/face_1.ppm
# Skipping data/train_crops/S421/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S421/face_1_shifted.ppm
# Skipping data/train_crops/S421/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S419/face_1_grayscale.ppm
# Skipping data/train_crops/S419/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S419/face_1_shifted.ppm
# Skipping data/train_crops/S419/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S409/face_1.ppm
# Skipping data/train_crops/S409/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S409/face_1_brightness.ppm
# Skipping data/train_crops/S409/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S409/face_1_grayscale.ppm
# Skipping data/train_crops/S409/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S409/face_1_shifted.ppm
# Skipping data/train_crops/S409/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S409/face_1_flipped.ppm
# Skipping data/train_crops/S409/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S423/face_1_shifted.ppm
# Skipping data/train_crops/S423/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S389/face_1_brightness.ppm
# Skipping data/train_crops/S389/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S215/face_1_shifted.ppm
# Skipping data/train_crops/S215/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S273/face_1_grayscale.ppm
# Skipping data/train_crops/S273/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S357/face_1_shifted.ppm
# Skipping data/train_crops/S357/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S367/face_1_grayscale.ppm
# Skipping data/train_crops/S367/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S367/face_1_shifted.ppm
# Skipping data/train_crops/S367/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S270/face_1.ppm
# Skipping data/train_crops/S270/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S270/face_1_brightness.ppm
# Skipping data/train_crops/S270/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S270/face_1_grayscale.ppm
# Skipping data/train_crops/S270/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S270/face_1_shifted.ppm
# Skipping data/train_crops/S270/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S270/face_1_flipped.ppm
# Skipping data/train_crops/S270/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S228/face_1.ppm
# Skipping data/train_crops/S228/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S228/face_1_grayscale.ppm
# Skipping data/train_crops/S228/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S228/face_1_shifted.ppm
# Skipping data/train_crops/S228/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S228/face_1_flipped.ppm
# Skipping data/train_crops/S228/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S280/face_1_shifted.ppm
# Skipping data/train_crops/S280/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S285/face_1.ppm
# Skipping data/train_crops/S285/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S285/face_1_brightness.ppm
# Skipping data/train_crops/S285/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S285/face_1_grayscale.ppm
# Skipping data/train_crops/S285/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S285/face_1_shifted.ppm
# Skipping data/train_crops/S285/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S285/face_1_flipped.ppm
# Skipping data/train_crops/S285/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S202/face_1.ppm
# Skipping data/train_crops/S202/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S202/face_1_brightness.ppm
# Skipping data/train_crops/S202/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S202/face_1_grayscale.ppm
# Skipping data/train_crops/S202/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S202/face_1_flipped.ppm
# Skipping data/train_crops/S202/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S261/face_1.ppm
# Skipping data/train_crops/S261/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S261/face_1_brightness.ppm
# Skipping data/train_crops/S261/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S261/face_1_grayscale.ppm
# Skipping data/train_crops/S261/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S261/face_1_shifted.ppm
# Skipping data/train_crops/S261/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S261/face_1_flipped.ppm
# Skipping data/train_crops/S261/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S249/face_1_shifted.ppm
# Skipping data/train_crops/S249/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S225/face_1_grayscale.ppm
# Skipping data/train_crops/S225/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S225/face_1_flipped.ppm
# Skipping data/train_crops/S225/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S150/face_1_grayscale.ppm
# Skipping data/train_crops/S150/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S150/face_1_shifted.ppm
# Skipping data/train_crops/S150/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S098/face_1.ppm
# Skipping data/train_crops/S098/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S098/face_1_brightness.ppm
# Skipping data/train_crops/S098/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S098/face_1_grayscale.ppm
# Skipping data/train_crops/S098/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S095/face_1.ppm
# Skipping data/train_crops/S095/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S095/face_1_brightness.ppm
# Skipping data/train_crops/S095/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S095/face_1_grayscale.ppm
# Skipping data/train_crops/S095/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S095/face_1_flipped.ppm
# Skipping data/train_crops/S095/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S085/face_1.ppm
# Skipping data/train_crops/S085/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S085/face_1_brightness.ppm
# Skipping data/train_crops/S085/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S085/face_1_grayscale.ppm
# Skipping data/train_crops/S085/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S033/face_1.ppm
# Skipping data/train_crops/S033/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S033/face_1_brightness.ppm
# Skipping data/train_crops/S033/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S033/face_1_grayscale.ppm
# Skipping data/train_crops/S033/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S033/face_1_shifted.ppm
# Skipping data/train_crops/S033/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S033/face_1_flipped.ppm
# Skipping data/train_crops/S033/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S099/face_1.ppm
# Skipping data/train_crops/S099/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S099/face_1_brightness.ppm
# Skipping data/train_crops/S099/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S099/face_1_grayscale.ppm
# Skipping data/train_crops/S099/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S099/face_1_shifted.ppm
# Skipping data/train_crops/S099/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S099/face_1_flipped.ppm
# Skipping data/train_crops/S099/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S073/face_1.ppm
# Skipping data/train_crops/S073/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S073/face_1_brightness.ppm
# Skipping data/train_crops/S073/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S073/face_1_grayscale.ppm
# Skipping data/train_crops/S073/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S073/face_1_shifted.ppm
# Skipping data/train_crops/S073/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S073/face_1_flipped.ppm
# Skipping data/train_crops/S073/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S076/face_1.ppm
# Skipping data/train_crops/S076/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S076/face_1_brightness.ppm
# Skipping data/train_crops/S076/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S076/face_1_grayscale.ppm
# Skipping data/train_crops/S076/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S076/face_1_shifted.ppm
# Skipping data/train_crops/S076/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S076/face_1_flipped.ppm
# Skipping data/train_crops/S076/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S069/face_1_shifted.ppm
# Skipping data/train_crops/S069/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S036/face_1.ppm
# Skipping data/train_crops/S036/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S036/face_1_brightness.ppm
# Skipping data/train_crops/S036/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S036/face_1_grayscale.ppm
# Skipping data/train_crops/S036/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S036/face_1_shifted.ppm
# Skipping data/train_crops/S036/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S036/face_1_flipped.ppm
# Skipping data/train_crops/S036/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S008/face_1_shifted.ppm
# Skipping data/train_crops/S008/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S030/face_1_grayscale.ppm
# Skipping data/train_crops/S030/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S030/face_1_shifted.ppm
# Skipping data/train_crops/S030/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S023/face_1.ppm
# Skipping data/train_crops/S023/face_1.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S023/face_1_brightness.ppm
# Skipping data/train_crops/S023/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S023/face_1_grayscale.ppm
# Skipping data/train_crops/S023/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S023/face_1_shifted.ppm
# Skipping data/train_crops/S023/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S023/face_1_flipped.ppm
# Skipping data/train_crops/S023/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S027/face_1_brightness.ppm
# Skipping data/train_crops/S027/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S027/face_1_grayscale.ppm
# Skipping data/train_crops/S027/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/train_crops/S027/face_1_shifted.ppm
# Skipping data/train_crops/S027/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S411/face_1.ppm
# Skipping data/val_crops/S411/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S411/face_1_brightness.ppm
# Skipping data/val_crops/S411/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S411/face_1_grayscale.ppm
# Skipping data/val_crops/S411/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S411/face_1_shifted.ppm
# Skipping data/val_crops/S411/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S411/face_1_flipped.ppm
# Skipping data/val_crops/S411/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S403/face_1_flipped.ppm
# Skipping data/val_crops/S403/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S422/face_1.ppm
# Skipping data/val_crops/S422/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S422/face_1_brightness.ppm
# Skipping data/val_crops/S422/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S422/face_1_grayscale.ppm
# Skipping data/val_crops/S422/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S422/face_1_shifted.ppm
# Skipping data/val_crops/S422/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S422/face_1_flipped.ppm
# Skipping data/val_crops/S422/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S413/face_1.ppm
# Skipping data/val_crops/S413/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S413/face_1_brightness.ppm
# Skipping data/val_crops/S413/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S413/face_1_grayscale.ppm
# Skipping data/val_crops/S413/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S413/face_1_shifted.ppm
# Skipping data/val_crops/S413/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S413/face_1_flipped.ppm
# Skipping data/val_crops/S413/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S404/face_1.ppm
# Skipping data/val_crops/S404/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S404/face_1_brightness.ppm
# Skipping data/val_crops/S404/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S404/face_1_grayscale.ppm
# Skipping data/val_crops/S404/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S259/face_1.ppm
# Skipping data/val_crops/S259/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S259/face_1_brightness.ppm
# Skipping data/val_crops/S259/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S259/face_1_grayscale.ppm
# Skipping data/val_crops/S259/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S259/face_1_shifted.ppm
# Skipping data/val_crops/S259/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S259/face_1_flipped.ppm
# Skipping data/val_crops/S259/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S400/face_1.ppm
# Skipping data/val_crops/S400/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S400/face_1_brightness.ppm
# Skipping data/val_crops/S400/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S400/face_1_grayscale.ppm
# Skipping data/val_crops/S400/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S400/face_1_shifted.ppm
# Skipping data/val_crops/S400/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S232/face_1.ppm
# Skipping data/val_crops/S232/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S232/face_1_brightness.ppm
# Skipping data/val_crops/S232/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S232/face_1_grayscale.ppm
# Skipping data/val_crops/S232/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S232/face_1_flipped.ppm
# Skipping data/val_crops/S232/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S201/face_1_grayscale.ppm
# Skipping data/val_crops/S201/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S193/face_1.ppm
# Skipping data/val_crops/S193/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S193/face_1_brightness.ppm
# Skipping data/val_crops/S193/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S193/face_1_grayscale.ppm
# Skipping data/val_crops/S193/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S193/face_1_shifted.ppm
# Skipping data/val_crops/S193/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S051/face_1_shifted.ppm
# Skipping data/val_crops/S051/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S146/face_1.ppm
# Skipping data/val_crops/S146/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S146/face_1_brightness.ppm
# Skipping data/val_crops/S146/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S146/face_1_grayscale.ppm
# Skipping data/val_crops/S146/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/
face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S180/face_1_shifted.ppm
# Skipping data/val_crops/S180/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S180/face_1_flipped.ppm
# Skipping data/val_crops/S180/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S015/face_1_brightness.ppm
# Skipping data/val_crops/S015/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S015/face_1_grayscale.ppm
# Skipping data/val_crops/S015/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S015/face_1_flipped.ppm
# Skipping data/val_crops/S015/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S399/face_1.ppm
# Skipping data/val_crops/S399/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S399/face_1_brightness.ppm
# Skipping data/val_crops/S399/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S399/face_1_shifted.ppm
# Skipping data/val_crops/S399/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S304/face_1.ppm
# Skipping data/val_crops/S304/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S304/face_1_brightness.ppm
# Skipping data/val_crops/S304/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S304/face_1_grayscale.ppm
# Skipping data/val_crops/S304/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S385/face_1_brightness.ppm
# Skipping data/val_crops/S385/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S280/face_1_flipped.ppm
# Skipping data/val_crops/S280/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S335/face_2.ppm
# Skipping data/val_crops/S335/face_2.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S335/face_2_brightness.ppm
# Skipping data/val_crops/S335/face_2_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S335/face_2_grayscale.ppm
# Skipping data/val_crops/S335/face_2_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S335/face_2_shifted.ppm
# Skipping data/val_crops/S335/face_2_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S335/face_2_flipped.ppm
# Skipping data/val_crops/S335/face_2_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S300/face_1.ppm
# Skipping data/val_crops/S300/face_1.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S300/face_1_brightness.ppm
# Skipping data/val_crops/S300/face_1_brightness.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S300/face_1_grayscale.ppm
# Skipping data/val_crops/S300/face_1_grayscale.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S300/face_1_shifted.ppm
# Skipping data/val_crops/S300/face_1_shifted.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S300/face_1_flipped.ppm
# Skipping data/val_crops/S300/face_1_flipped.ppm due to missing features
# Warning: No faces detected in image data/val_crops/S321/face_1_grayscale.ppm
# Skipping data/val_crops/S321/face_1_grayscale.ppm due to missing features
# Training data saved to npz/train.npz
# Validation data saved to npz/val.npz

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

def classify_with_knn(train_path, val_path, n_neighbors=5):
    """
    Perform classification using K-Nearest Neighbors and compute validation accuracy.

    Args:
        train_path (str): Path to the training .npz file.
        val_path (str): Path to the validation .npz file.
        n_neighbors (int): Number of neighbors for KNN.

    Returns:
        float: Validation accuracy.
    """
    # Load training data
    train_data = np.load(train_path)
    X_train = train_data['features']
    y_train = train_data['labels']

    # Load validation data
    val_data = np.load(val_path)
    X_val = val_data['features']
    y_val = val_data['labels']

    # Check and reshape if necessary
    if X_train.ndim == 1:
        X_train = X_train.reshape(-1, 1)
    if X_val.ndim == 1:
        X_val = X_val.reshape(-1, 1)

    if y_train.ndim == 1:
        y_train = y_train.reshape(-1)  # Ensure it's a 1D array
    if y_val.ndim == 1:
        y_val = y_val.reshape(-1)  # Ensure it's a 1D array

    # Initialize and train KNN classifier
    knn = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn.fit(X_train, y_train)

    # Predict on validation data
    y_pred = knn.predict(X_val)

    # Compute validation accuracy
    val_accuracy = accuracy_score(y_val, y_pred)
    print(f"Validation Accuracy: {val_accuracy* 100:.2f}%")

    # return val_accuracy

# Run KNN classification
train_file = 'npz/train.npz'
val_file = 'npz/val.npz'
classify_with_knn(train_file, val_file)
# Out:
# Validation Accuracy: 85.62%
